# %%
import pandas as pd

# %%
df = pd.read_csv("packets.csv")
df
# Out:
#                                           instruction  \
# 0   Analyze the network traffic pattern for suspic...
# 1   Analyze the network traffic pattern for suspic...
# 2   Analyze the network traffic pattern for suspic...
# 3   Analyze the network traffic pattern for suspic...
# 4   Analyze the network traffic pattern for suspic...
# 5   Analyze the network traffic pattern for suspic...
# 6   Analyze the network traffic pattern for suspic...
# 7   Analyze the network traffic pattern for suspic...
# 8   Analyze the network traffic pattern for suspic...
# 9   Analyze the network traffic pattern for suspic...
# 10  Analyze the network traffic pattern for suspic...
# 11  Analyze the network traffic pattern for suspic...
# 12  Analyze the network traffic pattern for suspic...
# 13  Analyze the network traffic pattern for suspic...
# 14  Analyze the network traffic pattern for suspic...
# 15  Analyze the network traffic pattern for suspic...
# ...
